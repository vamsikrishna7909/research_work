# %%
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import torch
import os
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
# Check GPU availability
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using GPU:", torch.cuda.get_device_name(0))
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Using GPU: NVIDIA L40

# %%
# Load pre-trained CLIP model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
model = model.to(device)

# %%
current_directory = os.getcwd()
print("Current working directory:", current_directory)
# Out:
# Current working directory: /home/jovyan/shared/clip_task

# %%
# Specify your directories
images_folder = "/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train"
captions_folder = "/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train"

# %%
# Helper function to recursively collect file paths
def collect_files(folder, extension):
    file_paths = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith(extension):
                file_paths.append(os.path.join(root, file))
    return sorted(file_paths)

# %%
# Collect image and caption files
image_files = collect_files(images_folder, '.png')[:1000]
caption_files = collect_files(captions_folder, '.txt')[:1000]

# %%
batch_size = 32  # Adjust based on your available memory
num_batches = len(image_files) // batch_size

# %%
'''# Process and encode the first 10,000 images and captions
batch_size = 32  # Adjust based on your available memory
image_files = sorted([f for f in os.listdir(images_folder) if os.path.isfile(os.path.join(images_folder, f)) and f.endswith('.png')])[:1000]
caption_files = sorted([f for f in os.listdir(captions_folder) if os.path.isfile(os.path.join(captions_folder, f)) and f.endswith('.txt')])[:1000]'''

if len(image_files) != len(caption_files):
    raise ValueError("The number of images and captions do not match.")

num_batches = len(image_files) // batch_size

# %%
# Initialize global lists for captions and image tensors
all_captions = []
all_image_tensors = []
all_image_files = []

image_features_list = []
text_features_list = []

for i in range(num_batches):
    batch_image_files = image_files[i * batch_size: (i + 1) * batch_size]
    batch_caption_files = caption_files[i * batch_size: (i + 1) * batch_size]

    # Debug: Print the current batch files
    print(f"Processing batch {i + 1}/{num_batches}")
    print(f"Batch image files: {batch_image_files}")
    print(f"Batch caption files: {batch_caption_files}")

    # Load and process images
    image_tensors = []
    for img_file in batch_image_files:
        try:
            image = Image.open(os.path.join(images_folder, img_file)).convert("RGB")
            image_tensors.append(image)
            all_image_files.append(img_file)  # Store the image file name

        except Exception as e:
            print(f"Error loading image {img_file}: {e}")

    # Load and process captions
    captions = []
    for cap_file in batch_caption_files:
        try:
            caption = open(os.path.join(captions_folder, cap_file)).read().strip()
            captions.append(caption)
        except Exception as e:
            print(f"Error loading caption {cap_file}: {e}")

    # Append to global lists
    all_captions.extend(captions)
    all_image_tensors.extend(image_tensors)
    
    # Print the features before encoding
    print(f"Before encoding - Batch {i + 1}:")
    print(f"Image tensors: {len(image_tensors)}, Captions: {len(captions)}")

    '''# Print the features before encoding
    if i == 0:  # Show features for the first batch only
        print(f"Before encoding - Batch {i + 1}:")
        print(f"Images (sample): {image_tensors[0].size}")
        print(f"Captions (sample): {captions[0]}")'''

    # Process batch if all files were loaded successfully
    if len(image_tensors) == len(batch_image_files) and len(captions) == len(batch_caption_files):
        inputs = processor(text=captions, images=image_tensors, return_tensors="pt", padding=True)
        
        # Move inputs to the device (GPU or CPU)
        inputs = {k: v.to(device) for k, v in inputs.items()}

        # Forward pass through CLIP model
        with torch.no_grad():
            outputs = model(**inputs)

         # Print the features after encoding
        '''if i == 0:  # Show features for the first batch only
            print(f"After encoding - Batch {i + 1}:")
            print(f"Image embeddings shape (sample): {outputs.image_embeds[0].shape}")
            print(f"Text embeddings shape (sample): {outputs.text_embeds[0].shape}")'''

        # Print the features after encoding
        print(f"After encoding - Batch {i + 1}:")
        print(f"Image embeddings shape: {outputs.image_embeds.shape}")
        print(f"Text embeddings shape: {outputs.text_embeds.shape}")

        # Normalize the embeddings
        image_embeds = outputs.image_embeds / outputs.image_embeds.norm(dim=-1, keepdim=True)
        text_embeds = outputs.text_embeds / outputs.text_embeds.norm(dim=-1, keepdim=True)

        # Print the features after normalization
        print(f"After normalization - Batch {i + 1}:")
        print(f"Normalized image embeddings shape: {image_embeds.shape}")
        print(f"Normalized text embeddings shape: {text_embeds.shape}")

        # Move outputs to CPU and store them
        image_features_list.append(image_embeds.cpu())
        text_features_list.append(text_embeds.cpu())
    else:
        print("Skipping batch due to errors in loading files.")
# Out:
# Processing batch 1/31
# Batch image files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/.ipynb_checkpoints/aachen_000000_000019_leftImg8bit-checkpoint.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/.ipynb_checkpoints/aachen_000001_000019_leftImg8bit-checkpoint.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/.ipynb_checkpoints/aachen_000003_000019_leftImg8bit-checkpoint.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/.ipynb_checkpoints/aachen_000008_000019_leftImg8bit-checkpoint.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/.ipynb_checkpoints/aachen_000015_000019_leftImg8bit-checkpoint.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000000_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000001_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000002_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000003_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000004_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000005_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000006_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000007_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000008_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000009_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000010_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000011_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000012_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000013_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000014_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000015_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000016_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000017_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000018_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000019_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000020_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000021_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000022_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000023_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000024_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000025_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000026_000019_leftImg8bit.png']
# Batch caption files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/.ipynb_checkpoints/aachen_000011_000019_leftImg8bit-checkpoint.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/.ipynb_checkpoints/aachen_000018_000019_leftImg8bit-checkpoint.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000000_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000001_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000002_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000003_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000004_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000005_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000006_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000007_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000008_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000009_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000010_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000011_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000012_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000013_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000014_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000015_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000016_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000017_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000018_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000019_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000020_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000021_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000022_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000023_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000024_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000025_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000026_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000027_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000028_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000029_000019_leftImg8bit.txt']
# Before encoding - Batch 1:
# Image tensors: 32, Captions: 32
# After encoding - Batch 1:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 1:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 2/31
# Batch image files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000027_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000028_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000029_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000030_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000031_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000032_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000033_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000034_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000035_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000036_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000037_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000038_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000039_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000040_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000041_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000042_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000043_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000044_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000045_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000046_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000047_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000048_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000049_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000050_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000051_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000052_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000053_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000054_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000055_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000056_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000057_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000058_000019_leftImg8bit.png']
# Batch caption files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000030_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000031_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000032_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000033_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000034_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000035_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000036_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000037_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000038_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000039_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000040_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000041_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000042_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000043_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000044_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000045_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000046_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000047_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000048_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000049_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000050_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000051_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000052_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000053_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000054_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000055_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000056_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000057_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000058_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000059_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000060_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000061_000019_leftImg8bit.txt']
# Before encoding - Batch 2:
# Image tensors: 32, Captions: 32
# After encoding - Batch 2:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 2:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 3/31
# Batch image files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000059_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000060_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000061_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000062_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000063_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000064_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000065_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000066_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000067_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000068_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000069_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000070_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000071_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000072_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000073_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000074_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000075_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000076_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000077_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000078_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000079_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000080_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000081_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000082_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000083_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000084_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000085_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000086_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000087_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000088_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000089_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000090_000019_leftImg8bit.png']
# Batch caption files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000062_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000063_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000064_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000065_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000066_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000067_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000068_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000069_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000070_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000071_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000072_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000073_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000074_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000075_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000076_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000077_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000078_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000079_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000080_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000081_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000082_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000083_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000084_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000085_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000086_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000087_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000088_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000089_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000090_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000091_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000092_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000093_000019_leftImg8bit.txt']
# Before encoding - Batch 3:
# Image tensors: 32, Captions: 32
# After encoding - Batch 3:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 3:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 4/31
# Batch image files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000091_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000092_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000093_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000094_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000095_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000096_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000097_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000098_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000099_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000100_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000101_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000102_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000103_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000104_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000105_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000106_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000107_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000108_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000109_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000110_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000111_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000112_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000113_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000114_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000115_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000116_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000117_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000118_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000119_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000120_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000121_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000122_000019_leftImg8bit.png']
# Batch caption files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000094_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000095_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000096_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000097_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000098_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000099_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000100_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000101_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000102_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000103_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000104_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000105_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000106_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000107_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000108_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000109_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000110_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000111_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000112_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000113_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000114_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000115_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000116_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000117_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000118_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000119_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000120_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000121_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000122_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000123_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000124_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000125_000019_leftImg8bit.txt']
# Before encoding - Batch 4:
# Image tensors: 32, Captions: 32
# After encoding - Batch 4:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 4:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 5/31
# Batch image files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000123_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000124_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000125_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000126_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000127_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000128_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000129_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000130_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000131_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000132_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000133_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000134_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000135_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000136_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000137_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000138_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000139_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000140_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000141_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000142_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000143_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000144_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000145_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000146_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000147_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000148_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000149_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000150_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000151_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000152_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000153_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000154_000019_leftImg8bit.png']
# Batch caption files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000126_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000127_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000128_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000129_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000130_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000131_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000132_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000133_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000134_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000135_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000136_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000137_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000138_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000139_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000140_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000141_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000142_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000143_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000144_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000145_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000146_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000147_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000148_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000149_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000150_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000151_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000152_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000153_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000154_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000155_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000156_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000157_000019_leftImg8bit.txt']
# Before encoding - Batch 5:
# Image tensors: 32, Captions: 32
# After encoding - Batch 5:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 5:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 6/31
# Batch image files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000155_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000156_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000157_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000158_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000159_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000160_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000161_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000162_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000163_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000164_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000165_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000166_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000167_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000168_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000169_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000170_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000171_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000172_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/aachen/aachen_000173_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_000313_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_000600_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_000885_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_001097_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_001519_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_001828_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_002293_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_002562_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_003005_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_003245_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_003674_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_004032_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/bochum/bochum_000000_004229_leftImg8bit.png']
# Batch caption files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000158_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000159_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000160_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000161_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000162_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000163_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000164_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000165_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000166_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000167_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000168_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000169_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000170_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000171_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000172_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/aachen/aachen_000173_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_000313_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_000600_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_000885_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_001097_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_001519_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_001828_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_002293_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_002562_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_003005_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_003245_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_003674_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_004032_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_004229_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_004748_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_005537_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/bochum/bochum_000000_005936_leftImg8bit.txt']
# Before encoding - Batch 6:
# Image tensors: 32, Captions: 32
# After encoding - Batch 6:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 6:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 7/31
# ...
# Batch caption files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000101_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000102_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000103_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000104_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000105_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000106_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000107_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000108_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000109_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000110_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000111_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000112_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000113_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000114_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000115_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000116_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000117_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000118_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000119_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000120_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000121_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000122_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000123_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000124_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000125_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000126_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000127_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000128_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000129_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000130_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000131_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000132_000019_leftImg8bit.txt']
# Before encoding - Batch 30:
# Image tensors: 32, Captions: 32
# After encoding - Batch 30:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 30:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 31/31
# Batch image files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000130_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000131_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000132_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000133_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000134_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000135_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000136_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000137_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000138_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000139_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000140_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000141_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000142_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000143_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000144_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000145_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000146_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000147_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000148_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000149_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000150_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000151_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000152_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000153_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000154_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000155_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000156_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000157_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000158_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000159_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000160_000019_leftImg8bit.png', '/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train/dusseldorf/dusseldorf_000161_000019_leftImg8bit.png']
# Batch caption files: ['/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000133_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000134_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000135_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000136_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000137_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000138_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000139_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000140_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000141_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000142_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000143_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000144_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000145_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000146_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000147_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000148_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000149_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000150_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000151_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000152_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000153_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000154_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000155_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000156_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000157_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000158_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000159_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000160_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000161_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000162_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000163_000019_leftImg8bit.txt', '/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train/dusseldorf/dusseldorf_000164_000019_leftImg8bit.txt']
# Before encoding - Batch 31:
# Image tensors: 32, Captions: 32
# After encoding - Batch 31:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 31:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])

# %%
# Concatenate features from all batches
image_features = torch.cat(image_features_list, dim=0)
text_features = torch.cat(text_features_list, dim=0)

# %%
# Print the concatenated features' dimensions
print(f"Concatenated image features shape: {image_features.shape}")
print(f"Concatenated text features shape: {text_features.shape}")
# Out:
# Concatenated image features shape: torch.Size([992, 512])
# Concatenated text features shape: torch.Size([992, 512])

# %%
# Compute cosine similarities between image features and caption features
cosine_similarities = F.cosine_similarity(
    image_features.unsqueeze(1),  # (num_images, 1, feature_dim)
    text_features.unsqueeze(0),  # (1, num_captions, feature_dim)
    dim=-1  # Compute similarity along the feature dimension
)

# Debug: Print shape of cosine_similarities
print(f"cosine_similarities shape: {cosine_similarities.shape}")
print(f"cosine_similarities: {cosine_similarities}")
# Out:
# cosine_similarities shape: torch.Size([992, 992])
# cosine_similarities: tensor([[0.2861, 0.2037, 0.2864,  ..., 0.2473, 0.2496, 0.2438],
#         [0.2879, 0.2423, 0.2742,  ..., 0.2703, 0.2386, 0.2485],
#         [0.2614, 0.2083, 0.2568,  ..., 0.2709, 0.2242, 0.2550],
#         ...,
#         [0.2677, 0.2062, 0.2426,  ..., 0.2667, 0.2461, 0.2467],
#         [0.2867, 0.2239, 0.2735,  ..., 0.2657, 0.2635, 0.2570],
#         [0.2884, 0.2131, 0.2759,  ..., 0.2833, 0.2828, 0.2529]])

# %%
def show_image(image_path):
    image = Image.open(os.path.join(images_folder, image_path))
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
# Function to find the most similar caption for a given image index
def find_most_similar_caption(image_idx):
    similarity_scores = cosine_similarities[image_idx]
    most_similar_caption_idx = torch.argmax(similarity_scores).item()
    print(f"Image index: {image_idx}, Most similar caption index: {most_similar_caption_idx}, Total captions: {len(all_captions)}")
    return all_captions[most_similar_caption_idx]

# Example usage
image_idx = 450  # Index of the image you want to query

# Show the original image
print("Original image:")
show_image(all_image_files[image_idx])

# Print the original caption and the most similar caption
print("Original caption:", all_captions[image_idx])
print("len of all captions", len(all_captions))
print("Most similar caption:", find_most_similar_caption(image_idx))
# Out:
# Original image:
# Original caption: cars driving down a street in a city with buildings and a tram
# len of all captions 992
# Image index: 450, Most similar caption index: 447, Total captions: 992
# Most similar caption: there is a view of a street with cars and bicycles on it

# %%
def find_most_similar_image(caption_idx):
    similarity_scores = cosine_similarities[:, caption_idx]
    most_similar_image_idx = torch.argmax(similarity_scores).item()
    print(f"Caption index: {caption_idx}, Most similar image index: {most_similar_image_idx}, Total images: {len(all_image_files)}")
    return all_image_files[most_similar_image_idx], most_similar_image_idx

# %%
caption_idx = 450  # Index of the caption you want to query

# Print the caption first
print(f"Original caption: {all_captions[caption_idx]}")

# Find and show the most similar image for the given caption
most_similar_image, most_similar_image_idx = find_most_similar_image(caption_idx)
print("Most similar image for the caption:")
show_image(most_similar_image)
# Out:
# Original caption: cars driving down a street in a city with buildings and a tram
# Caption index: 450, Most similar image index: 922, Total images: 992
# Most similar image for the caption:

# %%
# Paths to your image and caption folders
image_folder_path = '/home/jovyan/shared/test_images'
caption_folder_path = '/home/jovyan/shared/test_captions'

# Read all image files
all_image_files_test = [os.path.join(image_folder_path, fname) for fname in os.listdir(image_folder_path) if fname.endswith(('jpg', 'jpeg', 'png'))]

# Read all captions (assuming each caption is in a separate .txt file)
all_captions_test = []
caption_files = sorted([os.path.join(caption_folder_path, fname) for fname in os.listdir(caption_folder_path) if fname.endswith('.txt')])
for caption_file in caption_files:
    with open(caption_file, 'r') as f:
        all_captions_test.append(f.read().strip())

caption_idx = 1  # Index of the caption you want to query

# Print the caption first
print(f"Original caption: {all_captions_test[caption_idx]}")

# Find and show the most similar image for the given caption
most_similar_image, most_similar_image_idx = find_most_similar_image(caption_idx)
print("Most similar image for the caption:")
show_image(most_similar_image)
# Out:
# Original caption: there is a view of a street from a car window
# Caption index: 1, Most similar image index: 169, Total images: 992
# Most similar image for the caption:

# %%
# Example usage
image_idx = 1  # Index of the image you want to query

# Show the original image
print("Original image:")
show_image(all_image_files_test[image_idx])

# Print the original caption and the most similar caption
print("Original caption:", all_captions_test[image_idx])
print("len of all captions", len(all_captions))
print("Most similar caption:", find_most_similar_caption(image_idx))
# Out:
# Original image:
# Original caption: there is a view of a street from a car window
# len of all captions 992
# Image index: 1, Most similar caption index: 313, Total captions: 992
# Most similar caption: there is a car driving down a cobblestone street in a city
