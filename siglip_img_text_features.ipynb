# %%
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import torch
import os
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
# Check GPU availability
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using GPU:", torch.cuda.get_device_name(0))
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Using GPU: NVIDIA L40

# %%
# Load pre-trained CLIP model and processor
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
model = model.to(device)

# %%
current_directory = os.getcwd()
print("Current working directory:", current_directory)
# Out:
# Current working directory: /home/jovyan/shared/clip_task

# %%
# Specify your directories
images_folder = "/home/jovyan/shared/dataset/data_seg/cityscapes/leftImg8bit/train"
captions_folder = "/home/jovyan/shared/dataset/data_seg/cityscapes/captions/train"

# %%
# Helper function to recursively collect file paths
def collect_files(folder, extension):
    file_paths = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith(extension):
                file_paths.append(os.path.join(root, file))
    return sorted(file_paths)

# %%
# Collect image and caption files
image_files = collect_files(images_folder, '.png')[:1000]
caption_files = collect_files(captions_folder, '.txt')[:1000]

# %%
# Process and encode the first 10,000 images and captions
batch_size = 32  # Adjust based on your available memory
image_files = sorted([f for f in os.listdir(images_folder) if os.path.isfile(os.path.join(images_folder, f)) and f.endswith('.png')])[:1000]
caption_files = sorted([f for f in os.listdir(captions_folder) if os.path.isfile(os.path.join(captions_folder, f)) and f.endswith('.txt')])[:1000]

if len(image_files) != len(caption_files):
    raise ValueError("The number of images and captions do not match.")

num_batches = len(image_files) // batch_size

# %%
# Initialize global lists for captions and image tensors
all_captions = []
all_image_tensors = []
all_image_files = []

image_features_list = []
text_features_list = []

for i in range(num_batches):
    batch_image_files = image_files[i * batch_size: (i + 1) * batch_size]
    batch_caption_files = caption_files[i * batch_size: (i + 1) * batch_size]

    # Debug: Print the current batch files
    print(f"Processing batch {i + 1}/{num_batches}")
    print(f"Batch image files: {batch_image_files}")
    print(f"Batch caption files: {batch_caption_files}")

    # Load and process images
    image_tensors = []
    for img_file in batch_image_files:
        try:
            image = Image.open(os.path.join(images_folder, img_file)).convert("RGB")
            image_tensors.append(image)
            all_image_files.append(img_file)  # Store the image file name

        except Exception as e:
            print(f"Error loading image {img_file}: {e}")

    # Load and process captions
    captions = []
    for cap_file in batch_caption_files:
        try:
            caption = open(os.path.join(captions_folder, cap_file)).read().strip()
            captions.append(caption)
        except Exception as e:
            print(f"Error loading caption {cap_file}: {e}")

    # Append to global lists
    all_captions.extend(captions)
    all_image_tensors.extend(image_tensors)
    
    # Print the features before encoding
    print(f"Before encoding - Batch {i + 1}:")
    print(f"Image tensors: {len(image_tensors)}, Captions: {len(captions)}")

    '''# Print the features before encoding
    if i == 0:  # Show features for the first batch only
        print(f"Before encoding - Batch {i + 1}:")
        print(f"Images (sample): {image_tensors[0].size}")
        print(f"Captions (sample): {captions[0]}")'''

    # Process batch if all files were loaded successfully
    if len(image_tensors) == len(batch_image_files) and len(captions) == len(batch_caption_files):
        inputs = processor(text=captions, images=image_tensors, return_tensors="pt", padding=True)
        
        # Move inputs to the device (GPU or CPU)
        inputs = {k: v.to(device) for k, v in inputs.items()}

        # Forward pass through CLIP model
        with torch.no_grad():
            outputs = model(**inputs)

         # Print the features after encoding
        '''if i == 0:  # Show features for the first batch only
            print(f"After encoding - Batch {i + 1}:")
            print(f"Image embeddings shape (sample): {outputs.image_embeds[0].shape}")
            print(f"Text embeddings shape (sample): {outputs.text_embeds[0].shape}")'''

        # Print the features after encoding
        print(f"After encoding - Batch {i + 1}:")
        print(f"Image embeddings shape: {outputs.image_embeds.shape}")
        print(f"Text embeddings shape: {outputs.text_embeds.shape}")

        # Normalize the embeddings
        image_embeds = outputs.image_embeds / outputs.image_embeds.norm(dim=-1, keepdim=True)
        text_embeds = outputs.text_embeds / outputs.text_embeds.norm(dim=-1, keepdim=True)

        # Print the features after normalization
        print(f"After normalization - Batch {i + 1}:")
        print(f"Normalized image embeddings shape: {image_embeds.shape}")
        print(f"Normalized text embeddings shape: {text_embeds.shape}")

        # Move outputs to CPU and store them
        image_features_list.append(image_embeds.cpu())
        text_features_list.append(text_embeds.cpu())
    else:
        print("Skipping batch due to errors in loading files.")
# Out:
# Processing batch 1/31
# Batch image files: ['00001.png', '00002.png', '00003.png', '00004.png', '00005.png', '00006.png', '00007.png', '00008.png', '00009.png', '00010.png', '00011.png', '00012.png', '00013.png', '00014.png', '00015.png', '00016.png', '00017.png', '00018.png', '00019.png', '00020.png', '00021.png', '00022.png', '00023.png', '00024.png', '00025.png', '00026.png', '00027.png', '00028.png', '00029.png', '00030.png', '00031.png', '00032.png']
# Batch caption files: ['00001.txt', '00002.txt', '00003.txt', '00004.txt', '00005.txt', '00006.txt', '00007.txt', '00008.txt', '00009.txt', '00010.txt', '00011.txt', '00012.txt', '00013.txt', '00014.txt', '00015.txt', '00016.txt', '00017.txt', '00018.txt', '00019.txt', '00020.txt', '00021.txt', '00022.txt', '00023.txt', '00024.txt', '00025.txt', '00026.txt', '00027.txt', '00028.txt', '00029.txt', '00030.txt', '00031.txt', '00032.txt']
# Before encoding - Batch 1:
# Image tensors: 32, Captions: 32
# After encoding - Batch 1:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 1:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 2/31
# Batch image files: ['00033.png', '00034.png', '00035.png', '00036.png', '00037.png', '00038.png', '00039.png', '00040.png', '00041.png', '00042.png', '00043.png', '00044.png', '00045.png', '00046.png', '00047.png', '00048.png', '00049.png', '00050.png', '00051.png', '00052.png', '00053.png', '00054.png', '00055.png', '00056.png', '00057.png', '00058.png', '00059.png', '00060.png', '00061.png', '00062.png', '00063.png', '00064.png']
# Batch caption files: ['00033.txt', '00034.txt', '00035.txt', '00036.txt', '00037.txt', '00038.txt', '00039.txt', '00040.txt', '00041.txt', '00042.txt', '00043.txt', '00044.txt', '00045.txt', '00046.txt', '00047.txt', '00048.txt', '00049.txt', '00050.txt', '00051.txt', '00052.txt', '00053.txt', '00054.txt', '00055.txt', '00056.txt', '00057.txt', '00058.txt', '00059.txt', '00060.txt', '00061.txt', '00062.txt', '00063.txt', '00064.txt']
# Before encoding - Batch 2:
# Image tensors: 32, Captions: 32
# After encoding - Batch 2:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 2:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 3/31
# Batch image files: ['00065.png', '00066.png', '00067.png', '00068.png', '00069.png', '00070.png', '00071.png', '00072.png', '00073.png', '00074.png', '00075.png', '00076.png', '00077.png', '00078.png', '00079.png', '00080.png', '00081.png', '00082.png', '00083.png', '00084.png', '00085.png', '00086.png', '00087.png', '00088.png', '00089.png', '00090.png', '00091.png', '00092.png', '00093.png', '00094.png', '00095.png', '00096.png']
# Batch caption files: ['00065.txt', '00066.txt', '00067.txt', '00068.txt', '00069.txt', '00070.txt', '00071.txt', '00072.txt', '00073.txt', '00074.txt', '00075.txt', '00076.txt', '00077.txt', '00078.txt', '00079.txt', '00080.txt', '00081.txt', '00082.txt', '00083.txt', '00084.txt', '00085.txt', '00086.txt', '00087.txt', '00088.txt', '00089.txt', '00090.txt', '00091.txt', '00092.txt', '00093.txt', '00094.txt', '00095.txt', '00096.txt']
# Before encoding - Batch 3:
# Image tensors: 32, Captions: 32
# After encoding - Batch 3:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 3:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 4/31
# Batch image files: ['00097.png', '00098.png', '00099.png', '00100.png', '00101.png', '00102.png', '00103.png', '00104.png', '00105.png', '00106.png', '00107.png', '00108.png', '00109.png', '00110.png', '00111.png', '00112.png', '00113.png', '00114.png', '00115.png', '00116.png', '00117.png', '00118.png', '00119.png', '00120.png', '00121.png', '00122.png', '00123.png', '00124.png', '00125.png', '00126.png', '00127.png', '00128.png']
# Batch caption files: ['00097.txt', '00098.txt', '00099.txt', '00100.txt', '00101.txt', '00102.txt', '00103.txt', '00104.txt', '00105.txt', '00106.txt', '00107.txt', '00108.txt', '00109.txt', '00110.txt', '00111.txt', '00112.txt', '00113.txt', '00114.txt', '00115.txt', '00116.txt', '00117.txt', '00118.txt', '00119.txt', '00120.txt', '00121.txt', '00122.txt', '00123.txt', '00124.txt', '00125.txt', '00126.txt', '00127.txt', '00128.txt']
# Before encoding - Batch 4:
# Image tensors: 32, Captions: 32
# After encoding - Batch 4:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 4:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 5/31
# Batch image files: ['00129.png', '00130.png', '00131.png', '00132.png', '00133.png', '00134.png', '00135.png', '00136.png', '00137.png', '00138.png', '00139.png', '00140.png', '00141.png', '00142.png', '00143.png', '00144.png', '00145.png', '00146.png', '00147.png', '00148.png', '00149.png', '00150.png', '00151.png', '00152.png', '00153.png', '00154.png', '00155.png', '00156.png', '00157.png', '00158.png', '00159.png', '00160.png']
# Batch caption files: ['00129.txt', '00130.txt', '00131.txt', '00132.txt', '00133.txt', '00134.txt', '00135.txt', '00136.txt', '00137.txt', '00138.txt', '00139.txt', '00140.txt', '00141.txt', '00142.txt', '00143.txt', '00144.txt', '00145.txt', '00146.txt', '00147.txt', '00148.txt', '00149.txt', '00150.txt', '00151.txt', '00152.txt', '00153.txt', '00154.txt', '00155.txt', '00156.txt', '00157.txt', '00158.txt', '00159.txt', '00160.txt']
# Before encoding - Batch 5:
# Image tensors: 32, Captions: 32
# After encoding - Batch 5:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 5:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 6/31
# Batch image files: ['00161.png', '00162.png', '00163.png', '00164.png', '00165.png', '00166.png', '00167.png', '00168.png', '00169.png', '00170.png', '00171.png', '00172.png', '00173.png', '00174.png', '00175.png', '00176.png', '00177.png', '00178.png', '00179.png', '00180.png', '00181.png', '00182.png', '00183.png', '00184.png', '00185.png', '00186.png', '00187.png', '00188.png', '00189.png', '00190.png', '00191.png', '00192.png']

# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 25:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 26/31
# Batch image files: ['00801.png', '00802.png', '00803.png', '00804.png', '00805.png', '00806.png', '00807.png', '00808.png', '00809.png', '00810.png', '00811.png', '00812.png', '00813.png', '00814.png', '00815.png', '00816.png', '00817.png', '00818.png', '00819.png', '00820.png', '00821.png', '00822.png', '00823.png', '00824.png', '00825.png', '00826.png', '00827.png', '00828.png', '00829.png', '00830.png', '00831.png', '00832.png']
# Batch caption files: ['00801.txt', '00802.txt', '00803.txt', '00804.txt', '00805.txt', '00806.txt', '00807.txt', '00808.txt', '00809.txt', '00810.txt', '00811.txt', '00812.txt', '00813.txt', '00814.txt', '00815.txt', '00816.txt', '00817.txt', '00818.txt', '00819.txt', '00820.txt', '00821.txt', '00822.txt', '00823.txt', '00824.txt', '00825.txt', '00826.txt', '00827.txt', '00828.txt', '00829.txt', '00830.txt', '00831.txt', '00832.txt']
# Before encoding - Batch 26:
# Image tensors: 32, Captions: 32
# After encoding - Batch 26:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 26:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 27/31
# Batch image files: ['00833.png', '00834.png', '00835.png', '00836.png', '00837.png', '00838.png', '00839.png', '00840.png', '00841.png', '00842.png', '00843.png', '00844.png', '00845.png', '00846.png', '00847.png', '00848.png', '00849.png', '00850.png', '00851.png', '00852.png', '00853.png', '00854.png', '00855.png', '00856.png', '00857.png', '00858.png', '00859.png', '00860.png', '00861.png', '00862.png', '00863.png', '00864.png']
# Batch caption files: ['00833.txt', '00834.txt', '00835.txt', '00836.txt', '00837.txt', '00838.txt', '00839.txt', '00840.txt', '00841.txt', '00842.txt', '00843.txt', '00844.txt', '00845.txt', '00846.txt', '00847.txt', '00848.txt', '00849.txt', '00850.txt', '00851.txt', '00852.txt', '00853.txt', '00854.txt', '00855.txt', '00856.txt', '00857.txt', '00858.txt', '00859.txt', '00860.txt', '00861.txt', '00862.txt', '00863.txt', '00864.txt']
# Before encoding - Batch 27:
# Image tensors: 32, Captions: 32
# After encoding - Batch 27:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 27:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 28/31
# Batch image files: ['00865.png', '00866.png', '00867.png', '00868.png', '00869.png', '00870.png', '00871.png', '00872.png', '00873.png', '00874.png', '00875.png', '00876.png', '00877.png', '00878.png', '00879.png', '00880.png', '00881.png', '00882.png', '00883.png', '00884.png', '00885.png', '00886.png', '00887.png', '00888.png', '00889.png', '00890.png', '00891.png', '00892.png', '00893.png', '00894.png', '00895.png', '00896.png']
# Batch caption files: ['00865.txt', '00866.txt', '00867.txt', '00868.txt', '00869.txt', '00870.txt', '00871.txt', '00872.txt', '00873.txt', '00874.txt', '00875.txt', '00876.txt', '00877.txt', '00878.txt', '00879.txt', '00880.txt', '00881.txt', '00882.txt', '00883.txt', '00884.txt', '00885.txt', '00886.txt', '00887.txt', '00888.txt', '00889.txt', '00890.txt', '00891.txt', '00892.txt', '00893.txt', '00894.txt', '00895.txt', '00896.txt']
# Before encoding - Batch 28:
# Image tensors: 32, Captions: 32
# After encoding - Batch 28:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 28:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 29/31
# Batch image files: ['00897.png', '00898.png', '00899.png', '00900.png', '00901.png', '00902.png', '00903.png', '00904.png', '00905.png', '00906.png', '00907.png', '00908.png', '00909.png', '00910.png', '00911.png', '00912.png', '00913.png', '00914.png', '00915.png', '00916.png', '00917.png', '00918.png', '00919.png', '00920.png', '00921.png', '00922.png', '00923.png', '00924.png', '00925.png', '00926.png', '00927.png', '00928.png']
# Batch caption files: ['00897.txt', '00898.txt', '00899.txt', '00900.txt', '00901.txt', '00902.txt', '00903.txt', '00904.txt', '00905.txt', '00906.txt', '00907.txt', '00908.txt', '00909.txt', '00910.txt', '00911.txt', '00912.txt', '00913.txt', '00914.txt', '00915.txt', '00916.txt', '00917.txt', '00918.txt', '00919.txt', '00920.txt', '00921.txt', '00922.txt', '00923.txt', '00924.txt', '00925.txt', '00926.txt', '00927.txt', '00928.txt']
# Before encoding - Batch 29:
# Image tensors: 32, Captions: 32
# After encoding - Batch 29:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 29:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 30/31
# Batch image files: ['00929.png', '00930.png', '00931.png', '00932.png', '00933.png', '00934.png', '00935.png', '00936.png', '00937.png', '00938.png', '00939.png', '00940.png', '00941.png', '00942.png', '00943.png', '00944.png', '00945.png', '00946.png', '00947.png', '00948.png', '00949.png', '00950.png', '00951.png', '00952.png', '00953.png', '00954.png', '00955.png', '00956.png', '00957.png', '00958.png', '00959.png', '00960.png']
# Batch caption files: ['00929.txt', '00930.txt', '00931.txt', '00932.txt', '00933.txt', '00934.txt', '00935.txt', '00936.txt', '00937.txt', '00938.txt', '00939.txt', '00940.txt', '00941.txt', '00942.txt', '00943.txt', '00944.txt', '00945.txt', '00946.txt', '00947.txt', '00948.txt', '00949.txt', '00950.txt', '00951.txt', '00952.txt', '00953.txt', '00954.txt', '00955.txt', '00956.txt', '00957.txt', '00958.txt', '00959.txt', '00960.txt']
# Before encoding - Batch 30:
# Image tensors: 32, Captions: 32
# After encoding - Batch 30:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 30:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])
# Processing batch 31/31
# Batch image files: ['00961.png', '00962.png', '00963.png', '00964.png', '00965.png', '00966.png', '00967.png', '00968.png', '00969.png', '00970.png', '00971.png', '00972.png', '00973.png', '00974.png', '00975.png', '00976.png', '00977.png', '00978.png', '00979.png', '00980.png', '00981.png', '00982.png', '00983.png', '00984.png', '00985.png', '00986.png', '00987.png', '00988.png', '00989.png', '00990.png', '00991.png', '00992.png']
# Batch caption files: ['00961.txt', '00962.txt', '00963.txt', '00964.txt', '00965.txt', '00966.txt', '00967.txt', '00968.txt', '00969.txt', '00970.txt', '00971.txt', '00972.txt', '00973.txt', '00974.txt', '00975.txt', '00976.txt', '00977.txt', '00978.txt', '00979.txt', '00980.txt', '00981.txt', '00982.txt', '00983.txt', '00984.txt', '00985.txt', '00986.txt', '00987.txt', '00988.txt', '00989.txt', '00990.txt', '00991.txt', '00992.txt']
# Before encoding - Batch 31:
# Image tensors: 32, Captions: 32
# After encoding - Batch 31:
# Image embeddings shape: torch.Size([32, 512])
# Text embeddings shape: torch.Size([32, 512])
# After normalization - Batch 31:
# Normalized image embeddings shape: torch.Size([32, 512])
# Normalized text embeddings shape: torch.Size([32, 512])

# %%
# Concatenate features from all batches
image_features = torch.cat(image_features_list, dim=0)
text_features = torch.cat(text_features_list, dim=0)

# %%
# Print the concatenated features' dimensions
print(f"Concatenated image features shape: {image_features.shape}")
print(f"Concatenated text features shape: {text_features.shape}")
# Out:
# Concatenated image features shape: torch.Size([992, 512])
# Concatenated text features shape: torch.Size([992, 512])

# %%
# Compute cosine similarities between image features and caption features
cosine_similarities = F.cosine_similarity(
    image_features.unsqueeze(1),  # (num_images, 1, feature_dim)
    text_features.unsqueeze(0),  # (1, num_captions, feature_dim)
    dim=-1  # Compute similarity along the feature dimension
)

# Debug: Print shape of cosine_similarities
print(f"cosine_similarities shape: {cosine_similarities.shape}")
print(f"cosine_similarities: {cosine_similarities}")
# Out:
# cosine_similarities shape: torch.Size([992, 992])
# cosine_similarities: tensor([[0.2593, 0.2287, 0.2398,  ..., 0.2586, 0.2273, 0.2519],
#         [0.2397, 0.3112, 0.2382,  ..., 0.2782, 0.2676, 0.2521],
#         [0.2188, 0.2031, 0.2615,  ..., 0.2700, 0.2508, 0.2610],
#         ...,
#         [0.2039, 0.2165, 0.2771,  ..., 0.2891, 0.2197, 0.2659],
#         [0.1858, 0.2239, 0.2377,  ..., 0.2451, 0.2797, 0.2387],
#         [0.1981, 0.2122, 0.2776,  ..., 0.2972, 0.2317, 0.2722]])

# %%
def show_image(image_path):
    image = Image.open(os.path.join(images_folder, image_path))
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
# Function to find the most similar caption for a given image index
def find_most_similar_caption(image_idx):
    similarity_scores = cosine_similarities[image_idx]
    most_similar_caption_idx = torch.argmax(similarity_scores).item()
    print(f"Image index: {image_idx}, Most similar caption index: {most_similar_caption_idx}, Total captions: {len(all_captions)}")
    return all_captions[most_similar_caption_idx]

# Example usage
image_idx = 450  # Index of the image you want to query

# Show the original image
print("Original image:")
show_image(all_image_files[image_idx])

# Print the original caption and the most similar caption
print("Original caption:", all_captions[image_idx])
print("len of all captions", len(all_captions))
print("Most similar caption:", find_most_similar_caption(image_idx))
# Out:
# Original image:
# Original caption: there is a truck driving down the road in a game
# len of all captions 992
# Image index: 450, Most similar caption index: 808, Total captions: 992
# Most similar caption: there is a truck driving down the road in a virtual world

# %%
def find_most_similar_image(caption_idx):
    similarity_scores = cosine_similarities[:, caption_idx]
    most_similar_image_idx = torch.argmax(similarity_scores).item()
    print(f"Caption index: {caption_idx}, Most similar image index: {most_similar_image_idx}, Total images: {len(all_image_files)}")
    return all_image_files[most_similar_image_idx], most_similar_image_idx

caption_idx = 15  # Index of the caption you want to query

# Print the caption first
print(f"Original caption: {all_captions[caption_idx]}")

# Find and show the most similar image for the given caption
most_similar_image, most_similar_image_idx = find_most_similar_image(caption_idx)
print("Most similar image for the caption:")
show_image(most_similar_image)
# Out:
# Original caption: there is a car driving down a street in a city
# Caption index: 15, Most similar image index: 20, Total images: 992
# Most similar image for the caption:
